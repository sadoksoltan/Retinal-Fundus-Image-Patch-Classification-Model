# %%
import cv2
import numpy as np
from math import sqrt 
import numpy as np
from sys import exit
from PIL import Image
import matplotlib.pyplot as plt
import random

# %%
patchSize = 27     
patchPerImg = 1000  
numImage = 20       
totalPatch = patchPerImg * numImage
data = np.ones((totalPatch, patchSize, patchSize, 3), dtype='uint8')
dataLoc = np.ones((totalPatch, 2), dtype='uint8') 
dataLabel = np.ones((totalPatch), dtype='uint8') 

balance = 0.5 
positive = int(patchPerImg * balance) 
negative = patchPerImg - positive 
for i in range(1, numImage + 1):
    imgNum = str(i)
    if i < 10:
        imgNum = '0' + imgNum
    imgDir = "C:/Users/soltan/Desktop/project jupyter/DB"
    imgName = imgNum + '_test.tif'
    img = Image.open('C:/Users/soltan/Desktop/project jupyter/DB/test/images/' + imgName)
    maskName = imgNum + '_test_mask.gif'
    mask = Image.open('C:/Users/soltan/Desktop/project jupyter/DB/test/mask/' + maskName)
    gndTruthName = imgNum + '_manual1.gif'
    gndTruth = Image.open('C:/Users/soltan/Desktop/project jupyter/DB/test/1st_manual/' + gndTruthName)
    img = np.array(img)
    mask.convert('RGB')
    mask = np.array(mask)
    gndTruth = gndTruth.convert('RGB')
    gndTruth = np.array(gndTruth)[:,:,0]
    imgRow = img.shape[0]
    imgCol = img.shape[1]
    count = 0
    ind = (i - 1) * patchPerImg
    posCount = 0
    negCount = 0
    while count < patchPerImg:
        r = int(round(random.uniform(0, img.shape[0])))
        c = int(round(random.uniform(0, img.shape[1])))
        rStart = r - patchSize // 2
        rEnd = r + patchSize // 2 + 1
        cStart = c - patchSize // 2
        cEnd = c + patchSize // 2 + 1
        if np.all(mask[rStart:rEnd, cStart:cEnd]) and r > 13 and r < imgRow - 14 and c > 13 and c < imgCol - 14:
            label = gndTruth[r, c]
            if label == 0:
                if negCount == negative:
                    continue
                else:
                    negCount += 1
            else:
                if posCount == positive:
                    continue
                else:
                    posCount += 1
            
            temp = img[rStart:rEnd, cStart:cEnd, :]
        
            data[ind + count] = temp
            dataLoc[ind + count] = np.array([r, c])
            dataLabel[ind + count] = label
            
            
            count += 1
    print("Loaded image ", i)              
print(negCount, posCount)
print(patchPerImg)
print(patchSize)
print(data.shape)
print(np.count_nonzero(dataLabel))
np.save('C:/Users/soltan/Desktop/project jupyter/DB/testData', data)
np.save('C:/Users/soltan/Desktop/project jupyter/DB/testDataLcation',dataLoc)
np.save('C:/Users/soltan/Desktop/project jupyter/DB/testDataLabel',dataLabel)
# Out:
# Loaded image  1
# Loaded image  2
# Loaded image  3
# Loaded image  4
# Loaded image  5
# Loaded image  6
# Loaded image  7
# Loaded image  8
# Loaded image  9
# Loaded image  10
# Loaded image  11
# Loaded image  12
# Loaded image  13
# Loaded image  14
# Loaded image  15
# Loaded image  16
# Loaded image  17
# Loaded image  18
# Loaded image  19
# Loaded image  20
# 500 500
# 1000
# 27
# (20000, 27, 27, 3)
# 10000

# %%
patchSize = 27   
patchPerImg = 1000  
numImage = 20     
totalPatch = patchPerImg * numImage
datat = np.ones((totalPatch, patchSize, patchSize, 3), dtype='uint8') 
dataLoct = np.ones((totalPatch, 2), dtype='uint8') 
dataLabelt = np.ones((totalPatch), dtype='uint8') 

balance = 0.5 
positive = int(patchPerImg * balance) 
negative = patchPerImg - positive 
for i in range(1, numImage+1):
    imgNum = i
    if i < 22:
        imgNum = 20 + imgNum
    imgDir = "C:/Users/soltan/Desktop/project jupyter/DB"
    imgName = str(imgNum) + '_training.tif'
    img = Image.open('C:/Users/soltan/Desktop/project jupyter/DB/training/images/' + imgName)
    maskName = str(imgNum) + '_training_mask.gif'
    mask = Image.open('C:/Users/soltan/Desktop/project jupyter/DB/training/mask/' + maskName)
    gndTruthName = str(imgNum) + '_manual1.gif'
    gndTruth = Image.open('C:/Users/soltan/Desktop/project jupyter/DB/training/1st_manual/' + gndTruthName)
    img = np.array(img)
    mask.convert('RGB')
    mask = np.array(mask)
    gndTruth = gndTruth.convert('RGB')
    gndTruth = np.array(gndTruth)[:,:,0]
    imgRow = img.shape[0]
    imgCol = img.shape[1]
    count = 0
    ind = (i - 1) * patchPerImg
    posCount = 0
    negCount = 0
    while count < patchPerImg:
        r = int(round(random.uniform(0, img.shape[0])))
        c = int(round(random.uniform(0, img.shape[1])))
        rStart = r - patchSize // 2
        rEnd = r + patchSize // 2 + 1
        cStart = c - patchSize // 2
        cEnd = c + patchSize // 2 + 1
        if np.all(mask[rStart:rEnd, cStart:cEnd])  and r > 13 and r < imgRow - 14 and c > 13 and c < imgCol - 14:
            label = gndTruth[r, c]
            if label == 0:
                if negCount == negative:
                    continue
                else:
                    negCount += 1
            else:
                if posCount == positive:
                    continue
                else:
                    posCount += 1
            
            temp = img[rStart:rEnd, cStart:cEnd, :]
            datat[ind + count] = temp
            dataLoct[ind + count] = np.array([r, c])
            dataLabelt[ind + count] = label
            
            
            count += 1
    print("Loaded image ", i)   
print(len(datat))
print(negCount, posCount)
print(patchPerImg)
print(patchSize)
print(datat.shape)
print(np.count_nonzero(dataLabelt))
np.save('C:/Users/soltan/Desktop/project jupyter/DB/trainData', datat)
np.save('C:/Users/soltan/Desktop/project jupyter/DB/trainDataLcation',dataLoct)
np.save('C:/Users/soltan/Desktop/project jupyter/DB/trainDataLabel',dataLabelt)
# Out:
# Loaded image  1
# Loaded image  2
# Loaded image  3
# Loaded image  4
# Loaded image  5
# Loaded image  6
# Loaded image  7
# Loaded image  8
# Loaded image  9
# Loaded image  10
# Loaded image  11
# Loaded image  12
# Loaded image  13
# Loaded image  14
# Loaded image  15
# Loaded image  16
# Loaded image  17
# Loaded image  18
# Loaded image  19
# Loaded image  20
# 20000
# 500 500
# 1000
# 27
# (20000, 27, 27, 3)
# 10000

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
from sys import exit
from keras.applications import MobileNetV3Small, DenseNet121
from keras.layers import Input, Flatten, Dense, concatenate
from keras.models import Model

# %%
dir = 'C:/Users/soltan/Desktop/project jupyter/DB/testData.npy'
data_test= np.load(dir)
data_test = data_test[..., 1]
print(data_test.shape)
data_test = data_test.astype('uint8')
dir = 'C:/Users/soltan/Desktop/project jupyter/DB/testDataLabel.npy'
label_test = np.load(dir)
label_test =label_test.astype('uint8')
print(label_test.shape)
dir = 'C:/Users/soltan/Desktop/project jupyter/DB/trainData.npy'
data_train= np.load(dir)
data_train = data_train[..., 1]
print(data_train.shape)
data_train = data_train.astype('uint8')
dir = 'C:/Users/soltan/Desktop/project jupyter/DB/trainDataLabel.npy'
label_train = np.load(dir)
label_train = label_train.astype('uint8')
print(label_test.shape)
# Out:
# (20000, 27, 27)
# (20000,)
# (20000, 27, 27)
# (20000,)

# %%
plt.hist(data_test.flatten(), bins = 20)
plt.show()

# %%
fig = plt.figure(figsize = (6, 6))
fig.subplots_adjust(left = 0, right = 1, bottom = 0, top = 1, hspace = 0.05, wspace = 0.005)

l = np.random.randint(0, 20000, size = 42)
for i, j in enumerate(l):
	ax = fig.add_subplot(7, 7, i + 1)
	ax.imshow(data_test[j], cmap = 'binary')
	plt.axis('off')
plt.show()

# %%
plt.hist(data_train.flatten(), bins = 20)
plt.show()

# %%
fig = plt.figure(figsize = (6, 6))
fig.subplots_adjust(left = 0, right = 1, bottom = 0, top = 1, hspace = 0.05, wspace = 0.005)

l = np.random.randint(0, 20000, size = 42)
for i, j in enumerate(l):
	ax = fig.add_subplot(7, 7, i + 1)
	ax.imshow(data_train[j], cmap = 'binary')
	plt.axis('off')
plt.show()

# %%
import numpy as np
from tensorflow.keras.applications.densenet import DenseNet121
from keras.models import Sequential
from keras.layers import Dense, Activation
from keras.utils import np_utils
from keras import regularizers
from sys import exit
import tensorflow as tf
from keras.applications import DenseNet121, MobileNetV3Large, InceptionV3
from keras.regularizers import l2
from keras.models import Model
from tensorflow import keras
import matplotlib.pyplot as plt
from keras.layers import AveragePooling2D,GlobalAveragePooling2D
from tensorflow.keras import regularizers
from tensorflow.keras.layers import  Input, Dense,Conv2D, MaxPooling2D, Flatten, Dense, BatchNormalization, Dropout, concatenate,Reshape

# %%
x_train = data_train.reshape(20000,729).astype('float')
x_test = data_test.reshape(20000,729).astype('float')

x_train /= 255
x_test /= 255

label_train = (label_train / 255).astype('int')
y_train = np_utils.to_categorical(label_train, 2)

label_test = (label_test / 255).astype('int')
y_test = np_utils.to_categorical(label_test, 2)

# %%
from keras.wrappers.scikit_learn import KerasClassifier
from sklearn.ensemble import BaggingClassifier
from keras.applications import MobileNetV3Small
from keras import regularizers
from tensorflow.keras.callbacks import EarlyStopping

model = Sequential()
model.add(Dense(128, input_dim=729, activation='relu'))
model.add(Dense(2, activation='softmax', kernel_regularizer=regularizers.l2(0.0001)))
# Compiler le modèle
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
# Define the early stopping callback
early_stopping = EarlyStopping(monitor='val_loss', patience=5)
# Entraîner le modèle sur les données d'entraînement
history = model.fit(x_train, y_train, batch_size=128, epochs=200,verbose = 1, shuffle = False, validation_data = (x_test, y_test),callbacks=[early_stopping])
## score the model 
score = model.evaluate(x_test, y_test, verbose = 0)
print(model.metrics_names, score)
score = model.evaluate(x_train, y_train, verbose = 0)
print(model.metrics_names, score)
# Out:
# Epoch 1/200
# 157/157 [==============================] - 4s 13ms/step - loss: 0.7409 - accuracy: 0.4135 - val_loss: 0.6934 - val_accuracy: 0.5000
# Epoch 2/200
# 157/157 [==============================] - 2s 10ms/step - loss: 0.7016 - accuracy: 0.3924 - val_loss: 0.6918 - val_accuracy: 0.5000
# Epoch 3/200
# 157/157 [==============================] - 2s 10ms/step - loss: 0.6971 - accuracy: 0.4396 - val_loss: 0.6917 - val_accuracy: 0.5001
# Epoch 4/200
# 157/157 [==============================] - 1s 9ms/step - loss: 0.6953 - accuracy: 0.4623 - val_loss: 0.6914 - val_accuracy: 0.5000
# Epoch 5/200
# 157/157 [==============================] - 2s 10ms/step - loss: 0.6959 - accuracy: 0.4623 - val_loss: 0.6909 - val_accuracy: 0.5002
# Epoch 6/200
# 157/157 [==============================] - 1s 10ms/step - loss: 0.6950 - accuracy: 0.4457 - val_loss: 0.6909 - val_accuracy: 0.5088
# Epoch 7/200
# 157/157 [==============================] - 2s 10ms/step - loss: 0.6945 - accuracy: 0.4963 - val_loss: 0.6906 - val_accuracy: 0.5096
# Epoch 8/200
# 157/157 [==============================] - 1s 9ms/step - loss: 0.6937 - accuracy: 0.5095 - val_loss: 0.6899 - val_accuracy: 0.5060
# Epoch 9/200
# 157/157 [==============================] - 1s 10ms/step - loss: 0.6933 - accuracy: 0.5220 - val_loss: 0.6896 - val_accuracy: 0.5095
# Epoch 10/200
# 157/157 [==============================] - 1s 9ms/step - loss: 0.6956 - accuracy: 0.4986 - val_loss: 0.6893 - val_accuracy: 0.5001
# Epoch 11/200
# 157/157 [==============================] - 1s 10ms/step - loss: 0.6928 - accuracy: 0.5268 - val_loss: 0.6867 - val_accuracy: 0.5125
# Epoch 12/200
# 157/157 [==============================] - 1s 9ms/step - loss: 0.6913 - accuracy: 0.5453 - val_loss: 0.6850 - val_accuracy: 0.5102
# Epoch 13/200
# 157/157 [==============================] - 2s 10ms/step - loss: 0.6896 - accuracy: 0.5380 - val_loss: 0.6838 - val_accuracy: 0.5009
# Epoch 14/200
# 157/157 [==============================] - 2s 10ms/step - loss: 0.6899 - accuracy: 0.5350 - val_loss: 0.6777 - val_accuracy: 0.5066
# Epoch 15/200
# 157/157 [==============================] - 2s 10ms/step - loss: 0.6868 - accuracy: 0.5448 - val_loss: 0.6746 - val_accuracy: 0.5150
# Epoch 16/200
# 157/157 [==============================] - 2s 10ms/step - loss: 0.6808 - accuracy: 0.5562 - val_loss: 0.6857 - val_accuracy: 0.5016
# Epoch 17/200
# 157/157 [==============================] - 2s 10ms/step - loss: 0.6764 - accuracy: 0.5915 - val_loss: 0.6728 - val_accuracy: 0.5085
# Epoch 18/200
# 157/157 [==============================] - 2s 10ms/step - loss: 0.6707 - accuracy: 0.6069 - val_loss: 0.6845 - val_accuracy: 0.5063
# Epoch 19/200
# 157/157 [==============================] - 2s 10ms/step - loss: 0.6632 - accuracy: 0.6137 - val_loss: 0.6886 - val_accuracy: 0.5096
# Epoch 20/200
# 157/157 [==============================] - 2s 10ms/step - loss: 0.6530 - accuracy: 0.6307 - val_loss: 0.6802 - val_accuracy: 0.5174
# Epoch 21/200
# 157/157 [==============================] - 2s 10ms/step - loss: 0.6430 - accuracy: 0.6382 - val_loss: 0.6669 - val_accuracy: 0.5278
# Epoch 22/200
# 157/157 [==============================] - 2s 10ms/step - loss: 0.6321 - accuracy: 0.6485 - val_loss: 0.6584 - val_accuracy: 0.5364
# Epoch 23/200
# 157/157 [==============================] - 2s 10ms/step - loss: 0.6225 - accuracy: 0.6583 - val_loss: 0.6457 - val_accuracy: 0.5487
# Epoch 24/200
# 157/157 [==============================] - 2s 10ms/step - loss: 0.6138 - accuracy: 0.6654 - val_loss: 0.6331 - val_accuracy: 0.5626
# Epoch 25/200
# 157/157 [==============================] - 2s 10ms/step - loss: 0.6060 - accuracy: 0.6719 - val_loss: 0.6215 - val_accuracy: 0.5788
# Epoch 26/200
# 157/157 [==============================] - 2s 10ms/step - loss: 0.5992 - accuracy: 0.6806 - val_loss: 0.6126 - val_accuracy: 0.5900
# Epoch 27/200
# 157/157 [==============================] - 2s 10ms/step - loss: 0.5939 - accuracy: 0.6865 - val_loss: 0.6056 - val_accuracy: 0.6006
# Epoch 28/200
# 157/157 [==============================] - 2s 10ms/step - loss: 0.5889 - accuracy: 0.6921 - val_loss: 0.5986 - val_accuracy: 0.6111
# Epoch 29/200
# 157/157 [==============================] - 2s 10ms/step - loss: 0.5842 - accuracy: 0.6984 - val_loss: 0.5934 - val_accuracy: 0.6190
# Epoch 30/200
# 157/157 [==============================] - 2s 10ms/step - loss: 0.5799 - accuracy: 0.7019 - val_loss: 0.5864 - val_accuracy: 0.6287
# Epoch 31/200
# 157/157 [==============================] - 2s 10ms/step - loss: 0.5757 - accuracy: 0.7051 - val_loss: 0.5823 - val_accuracy: 0.6340
# Epoch 32/200
# 157/157 [==============================] - 1s 10ms/step - loss: 0.5720 - accuracy: 0.7088 - val_loss: 0.5772 - val_accuracy: 0.6416
# Epoch 33/200
# 157/157 [==============================] - 1s 9ms/step - loss: 0.5686 - accuracy: 0.7117 - val_loss: 0.5741 - val_accuracy: 0.6460
# Epoch 34/200
# 157/157 [==============================] - 1s 9ms/step - loss: 0.5656 - accuracy: 0.7146 - val_loss: 0.5709 - val_accuracy: 0.6502
# Epoch 35/200
# 157/157 [==============================] - 2s 10ms/step - loss: 0.5625 - accuracy: 0.7176 - val_loss: 0.5676 - val_accuracy: 0.6550
# Epoch 36/200
# 157/157 [==============================] - 2s 10ms/step - loss: 0.5598 - accuracy: 0.7207 - val_loss: 0.5649 - val_accuracy: 0.6594
# Epoch 37/200
# 157/157 [==============================] - 1s 9ms/step - loss: 0.5573 - accuracy: 0.7222 - val_loss: 0.5640 - val_accuracy: 0.6608
# Epoch 38/200
# 157/157 [==============================] - 2s 10ms/step - loss: 0.5551 - accuracy: 0.7242 - val_loss: 0.5624 - val_accuracy: 0.6646
# Epoch 39/200
# 157/157 [==============================] - 2s 10ms/step - loss: 0.5527 - accuracy: 0.7265 - val_loss: 0.5601 - val_accuracy: 0.6668
# Epoch 40/200
# 157/157 [==============================] - 1s 9ms/step - loss: 0.5503 - accuracy: 0.7287 - val_loss: 0.5582 - val_accuracy: 0.6702
# Epoch 41/200
# 157/157 [==============================] - 1s 10ms/step - loss: 0.5484 - accuracy: 0.7307 - val_loss: 0.5565 - val_accuracy: 0.6716
# Epoch 42/200
# 157/157 [==============================] - 2s 10ms/step - loss: 0.5466 - accuracy: 0.7318 - val_loss: 0.5556 - val_accuracy: 0.6732
# Epoch 43/200
# 157/157 [==============================] - 2s 10ms/step - loss: 0.5448 - accuracy: 0.7336 - val_loss: 0.5553 - val_accuracy: 0.6739
# Epoch 44/200
# 157/157 [==============================] - 1s 9ms/step - loss: 0.5432 - accuracy: 0.7347 - val_loss: 0.5539 - val_accuracy: 0.6752
# Epoch 45/200
# 157/157 [==============================] - 1s 9ms/step - loss: 0.5414 - accuracy: 0.7355 - val_loss: 0.5528 - val_accuracy: 0.6768
# Epoch 46/200
# 157/157 [==============================] - 2s 10ms/step - loss: 0.5397 - accuracy: 0.7369 - val_loss: 0.5516 - val_accuracy: 0.6784
# Epoch 47/200
# 157/157 [==============================] - 2s 10ms/step - loss: 0.5381 - accuracy: 0.7381 - val_loss: 0.5507 - val_accuracy: 0.6804
# Epoch 48/200
# 157/157 [==============================] - 2s 10ms/step - loss: 0.5369 - accuracy: 0.7389 - val_loss: 0.5507 - val_accuracy: 0.6802
# Epoch 49/200
# 157/157 [==============================] - 2s 11ms/step - loss: 0.5359 - accuracy: 0.7398 - val_loss: 0.5505 - val_accuracy: 0.6808
# Epoch 50/200
# 157/157 [==============================] - 1s 9ms/step - loss: 0.5346 - accuracy: 0.7407 - val_loss: 0.5500 - val_accuracy: 0.6816
# Epoch 51/200
# 157/157 [==============================] - 2s 10ms/step - loss: 0.5330 - accuracy: 0.7418 - val_loss: 0.5490 - val_accuracy: 0.6833
# Epoch 52/200
# 157/157 [==============================] - 2s 11ms/step - loss: 0.5316 - accuracy: 0.7430 - val_loss: 0.5482 - val_accuracy: 0.6844
# Epoch 53/200
# 157/157 [==============================] - 2s 10ms/step - loss: 0.5305 - accuracy: 0.7438 - val_loss: 0.5480 - val_accuracy: 0.6845
# Epoch 54/200
# 157/157 [==============================] - 2s 11ms/step - loss: 0.5295 - accuracy: 0.7444 - val_loss: 0.5480 - val_accuracy: 0.6847
# Epoch 55/200
# 157/157 [==============================] - 1s 8ms/step - loss: 0.5284 - accuracy: 0.7454 - val_loss: 0.5476 - val_accuracy: 0.6853
# Epoch 56/200
# 157/157 [==============================] - 1s 9ms/step - loss: 0.5274 - accuracy: 0.7460 - val_loss: 0.5467 - val_accuracy: 0.6866
# Epoch 57/200
# 157/157 [==============================] - 1s 9ms/step - loss: 0.5263 - accuracy: 0.7469 - val_loss: 0.5469 - val_accuracy: 0.6866
# Epoch 58/200
# 157/157 [==============================] - 1s 8ms/step - loss: 0.5254 - accuracy: 0.7477 - val_loss: 0.5460 - val_accuracy: 0.6878
# Epoch 59/200
# 157/157 [==============================] - 1s 9ms/step - loss: 0.5245 - accuracy: 0.7481 - val_loss: 0.5455 - val_accuracy: 0.6886
# Epoch 60/200
# 157/157 [==============================] - 2s 10ms/step - loss: 0.5236 - accuracy: 0.7484 - val_loss: 0.5453 - val_accuracy: 0.6892
# Epoch 61/200
# 157/157 [==============================] - 1s 9ms/step - loss: 0.5228 - accuracy: 0.7495 - val_loss: 0.5447 - val_accuracy: 0.6901
# Epoch 62/200
# 157/157 [==============================] - 2s 12ms/step - loss: 0.5221 - accuracy: 0.7500 - val_loss: 0.5444 - val_accuracy: 0.6906
# Epoch 63/200
# 157/157 [==============================] - 1s 9ms/step - loss: 0.5213 - accuracy: 0.7509 - val_loss: 0.5448 - val_accuracy: 0.6903
# Epoch 64/200
# 157/157 [==============================] - 1s 9ms/step - loss: 0.5204 - accuracy: 0.7513 - val_loss: 0.5437 - val_accuracy: 0.6914
# Epoch 65/200
# 157/157 [==============================] - 1s 9ms/step - loss: 0.5196 - accuracy: 0.7520 - val_loss: 0.5428 - val_accuracy: 0.6923
# Epoch 66/200
# 157/157 [==============================] - 2s 10ms/step - loss: 0.5186 - accuracy: 0.7527 - val_loss: 0.5413 - val_accuracy: 0.6934
# Epoch 67/200
# 157/157 [==============================] - 1s 10ms/step - loss: 0.5178 - accuracy: 0.7534 - val_loss: 0.5398 - val_accuracy: 0.6952
# Epoch 68/200
# 157/157 [==============================] - 1s 9ms/step - loss: 0.5169 - accuracy: 0.7538 - val_loss: 0.5391 - val_accuracy: 0.6959
# Epoch 69/200
# 157/157 [==============================] - 1s 10ms/step - loss: 0.5162 - accuracy: 0.7542 - val_loss: 0.5387 - val_accuracy: 0.6966
# Epoch 70/200
# 157/157 [==============================] - 1s 9ms/step - loss: 0.5155 - accuracy: 0.7549 - val_loss: 0.5382 - val_accuracy: 0.6973
# Epoch 71/200
# 157/157 [==============================] - 2s 10ms/step - loss: 0.5147 - accuracy: 0.7556 - val_loss: 0.5370 - val_accuracy: 0.6991
# Epoch 72/200
# 157/157 [==============================] - 1s 9ms/step - loss: 0.5138 - accuracy: 0.7561 - val_loss: 0.5365 - val_accuracy: 0.6993
# Epoch 73/200
# 157/157 [==============================] - 1s 9ms/step - loss: 0.5133 - accuracy: 0.7563 - val_loss: 0.5362 - val_accuracy: 0.6998
# Epoch 74/200
# 157/157 [==============================] - 2s 10ms/step - loss: 0.5124 - accuracy: 0.7569 - val_loss: 0.5352 - val_accuracy: 0.7006
# Epoch 75/200
# 157/157 [==============================] - 2s 10ms/step - loss: 0.5119 - accuracy: 0.7574 - val_loss: 0.5348 - val_accuracy: 0.7010
# Epoch 76/200
# 157/157 [==============================] - 1s 9ms/step - loss: 0.5112 - accuracy: 0.7577 - val_loss: 0.5342 - val_accuracy: 0.7017
# Epoch 77/200
# 157/157 [==============================] - 1s 9ms/step - loss: 0.5106 - accuracy: 0.7580 - val_loss: 0.5334 - val_accuracy: 0.7025
# Epoch 78/200
# 157/157 [==============================] - 2s 10ms/step - loss: 0.5098 - accuracy: 0.7585 - val_loss: 0.5321 - val_accuracy: 0.7034
# Epoch 79/200
# 157/157 [==============================] - 1s 9ms/step - loss: 0.5090 - accuracy: 0.7592 - val_loss: 0.5315 - val_accuracy: 0.7038
# Epoch 80/200
# 157/157 [==============================] - 1s 9ms/step - loss: 0.5084 - accuracy: 0.7595 - val_loss: 0.5307 - val_accuracy: 0.7049
# Epoch 81/200
# 157/157 [==============================] - 2s 10ms/step - loss: 0.5080 - accuracy: 0.7597 - val_loss: 0.5306 - val_accuracy: 0.7053
# Epoch 82/200
# 157/157 [==============================] - 1s 9ms/step - loss: 0.5075 - accuracy: 0.7603 - val_loss: 0.5300 - val_accuracy: 0.7057
# Epoch 83/200
# 157/157 [==============================] - 1s 9ms/step - loss: 0.5069 - accuracy: 0.7607 - val_loss: 0.5301 - val_accuracy: 0.7056
# Epoch 84/200
# 157/157 [==============================] - 1s 9ms/step - loss: 0.5064 - accuracy: 0.7611 - val_loss: 0.5298 - val_accuracy: 0.7060
# Epoch 85/200
# 157/157 [==============================] - 1s 9ms/step - loss: 0.5059 - accuracy: 0.7617 - val_loss: 0.5296 - val_accuracy: 0.7064
# Epoch 86/200
# 157/157 [==============================] - 1s 9ms/step - loss: 0.5053 - accuracy: 0.7623 - val_loss: 0.5283 - val_accuracy: 0.7076
# Epoch 87/200
# 157/157 [==============================] - 1s 9ms/step - loss: 0.5047 - accuracy: 0.7626 - val_loss: 0.5280 - val_accuracy: 0.7082
# Epoch 88/200
# 157/157 [==============================] - 1s 9ms/step - loss: 0.5040 - accuracy: 0.7630 - val_loss: 0.5276 - val_accuracy: 0.7087
# Epoch 89/200
# 157/157 [==============================] - 1s 10ms/step - loss: 0.5035 - accuracy: 0.7632 - val_loss: 0.5274 - val_accuracy: 0.7092
# Epoch 90/200
# 157/157 [==============================] - 1s 9ms/step - loss: 0.5030 - accuracy: 0.7635 - val_loss: 0.5268 - val_accuracy: 0.7095
# Epoch 91/200
# 157/157 [==============================] - 1s 9ms/step - loss: 0.5025 - accuracy: 0.7641 - val_loss: 0.5260 - val_accuracy: 0.7106
# Epoch 92/200
# 157/157 [==============================] - 1s 9ms/step - loss: 0.5019 - accuracy: 0.7644 - val_loss: 0.5255 - val_accuracy: 0.7110
# Epoch 93/200
# 157/157 [==============================] - 1s 9ms/step - loss: 0.5014 - accuracy: 0.7646 - val_loss: 0.5251 - val_accuracy: 0.7108
# Epoch 94/200
# 157/157 [==============================] - 2s 10ms/step - loss: 0.5009 - accuracy: 0.7650 - val_loss: 0.5250 - val_accuracy: 0.7110
# Epoch 95/200
# 157/157 [==============================] - 1s 9ms/step - loss: 0.5003 - accuracy: 0.7656 - val_loss: 0.5241 - val_accuracy: 0.7118
# Epoch 96/200
# 157/157 [==============================] - 1s 9ms/step - loss: 0.4997 - accuracy: 0.7659 - val_loss: 0.5233 - val_accuracy: 0.7129
# Epoch 97/200
# 157/157 [==============================] - 1s 9ms/step - loss: 0.4993 - accuracy: 0.7660 - val_loss: 0.5223 - val_accuracy: 0.7139
# Epoch 98/200
# 157/157 [==============================] - 1s 9ms/step - loss: 0.4987 - accuracy: 0.7661 - val_loss: 0.5219 - val_accuracy: 0.7146
# Epoch 99/200
# 157/157 [==============================] - 1s 10ms/step - loss: 0.4982 - accuracy: 0.7662 - val_loss: 0.5212 - val_accuracy: 0.7151
# Epoch 100/200
# 157/157 [==============================] - 1s 9ms/step - loss: 0.4978 - accuracy: 0.7667 - val_loss: 0.5210 - val_accuracy: 0.7153
# Epoch 101/200
# 157/157 [==============================] - 1s 9ms/step - loss: 0.4973 - accuracy: 0.7671 - val_loss: 0.5207 - val_accuracy: 0.7155
# Epoch 102/200
# 157/157 [==============================] - 1s 9ms/step - loss: 0.4969 - accuracy: 0.7675 - val_loss: 0.5202 - val_accuracy: 0.7161
# Epoch 103/200
# 157/157 [==============================] - 1s 9ms/step - loss: 0.4965 - accuracy: 0.7678 - val_loss: 0.5202 - val_accuracy: 0.7161
# Epoch 104/200
# 157/157 [==============================] - 2s 10ms/step - loss: 0.4961 - accuracy: 0.7680 - val_loss: 0.5199 - val_accuracy: 0.7167
# Epoch 105/200
# 157/157 [==============================] - 1s 9ms/step - loss: 0.4956 - accuracy: 0.7684 - val_loss: 0.5194 - val_accuracy: 0.7172
# Epoch 106/200
# 157/157 [==============================] - 1s 9ms/step - loss: 0.4954 - accuracy: 0.7687 - val_loss: 0.5194 - val_accuracy: 0.7167
# Epoch 107/200
# 157/157 [==============================] - 1s 10ms/step - loss: 0.4950 - accuracy: 0.7690 - val_loss: 0.5190 - val_accuracy: 0.7170
# Epoch 108/200
# 157/157 [==============================] - 1s 9ms/step - loss: 0.4946 - accuracy: 0.7690 - val_loss: 0.5185 - val_accuracy: 0.7175
# Epoch 109/200
# 157/157 [==============================] - 1s 9ms/step - loss: 0.4941 - accuracy: 0.7695 - val_loss: 0.5178 - val_accuracy: 0.7182
# Epoch 110/200
# 157/157 [==============================] - 2s 10ms/step - loss: 0.4937 - accuracy: 0.7697 - val_loss: 0.5174 - val_accuracy: 0.7185
# Epoch 111/200
# 157/157 [==============================] - 1s 9ms/step - loss: 0.4932 - accuracy: 0.7701 - val_loss: 0.5168 - val_accuracy: 0.7191
# Epoch 112/200
# 157/157 [==============================] - 1s 9ms/step - loss: 0.4928 - accuracy: 0.7705 - val_loss: 0.5170 - val_accuracy: 0.7189
# Epoch 113/200
# 157/157 [==============================] - 2s 10ms/step - loss: 0.4924 - accuracy: 0.7706 - val_loss: 0.5165 - val_accuracy: 0.7194
# Epoch 114/200
# 157/157 [==============================] - 1s 9ms/step - loss: 0.4919 - accuracy: 0.7710 - val_loss: 0.5163 - val_accuracy: 0.7196
# Epoch 115/200
# 157/157 [==============================] - 2s 10ms/step - loss: 0.4916 - accuracy: 0.7711 - val_loss: 0.5159 - val_accuracy: 0.7200
# Epoch 116/200
# 157/157 [==============================] - 2s 10ms/step - loss: 0.4912 - accuracy: 0.7715 - val_loss: 0.5146 - val_accuracy: 0.7210
# Epoch 117/200
# 157/157 [==============================] - 2s 10ms/step - loss: 0.4907 - accuracy: 0.7721 - val_loss: 0.5140 - val_accuracy: 0.7214
# Epoch 118/200
# 157/157 [==============================] - 1s 9ms/step - loss: 0.4904 - accuracy: 0.7724 - val_loss: 0.5140 - val_accuracy: 0.7216
# Epoch 119/200
# 157/157 [==============================] - 1s 10ms/step - loss: 0.4900 - accuracy: 0.7728 - val_loss: 0.5128 - val_accuracy: 0.7230
# Epoch 120/200
# 157/157 [==============================] - 1s 9ms/step - loss: 0.4896 - accuracy: 0.7732 - val_loss: 0.5122 - val_accuracy: 0.7235
# Epoch 121/200
# 157/157 [==============================] - 1s 9ms/step - loss: 0.4892 - accuracy: 0.7734 - val_loss: 0.5118 - val_accuracy: 0.7240
# Epoch 122/200
# 157/157 [==============================] - 1s 9ms/step - loss: 0.4888 - accuracy: 0.7738 - val_loss: 0.5114 - val_accuracy: 0.7243
# Epoch 123/200
# 157/157 [==============================] - 2s 10ms/step - loss: 0.4884 - accuracy: 0.7742 - val_loss: 0.5112 - val_accuracy: 0.7243
# Epoch 124/200
# 157/157 [==============================] - 1s 10ms/step - loss: 0.4882 - accuracy: 0.7746 - val_loss: 0.5110 - val_accuracy: 0.7248
# Epoch 125/200
# 157/157 [==============================] - 2s 10ms/step - loss: 0.4878 - accuracy: 0.7747 - val_loss: 0.5106 - val_accuracy: 0.7253
# Epoch 126/200
# 157/157 [==============================] - 1s 9ms/step - loss: 0.4874 - accuracy: 0.7749 - val_loss: 0.5102 - val_accuracy: 0.7258
# Epoch 127/200
# 157/157 [==============================] - 1s 9ms/step - loss: 0.4871 - accuracy: 0.7750 - val_loss: 0.5099 - val_accuracy: 0.7260
# Epoch 128/200
# 157/157 [==============================] - 1s 9ms/step - loss: 0.4866 - accuracy: 0.7752 - val_loss: 0.5096 - val_accuracy: 0.7263
# Epoch 129/200
# 157/157 [==============================] - 1s 9ms/step - loss: 0.4864 - accuracy: 0.7752 - val_loss: 0.5095 - val_accuracy: 0.7265
# Epoch 130/200
# 157/157 [==============================] - 2s 10ms/step - loss: 0.4861 - accuracy: 0.7750 - val_loss: 0.5094 - val_accuracy: 0.7266
# Epoch 131/200
# 157/157 [==============================] - 1s 9ms/step - loss: 0.4857 - accuracy: 0.7753 - val_loss: 0.5090 - val_accuracy: 0.7270
# Epoch 132/200
# 157/157 [==============================] - 1s 9ms/step - loss: 0.4854 - accuracy: 0.7756 - val_loss: 0.5087 - val_accuracy: 0.7273
# Epoch 133/200
# 157/157 [==============================] - 2s 10ms/step - loss: 0.4851 - accuracy: 0.7760 - val_loss: 0.5084 - val_accuracy: 0.7276
# Epoch 134/200
# 157/157 [==============================] - 1s 9ms/step - loss: 0.4848 - accuracy: 0.7764 - val_loss: 0.5082 - val_accuracy: 0.7278
# Epoch 135/200
# 157/157 [==============================] - 1s 9ms/step - loss: 0.4844 - accuracy: 0.7768 - val_loss: 0.5076 - val_accuracy: 0.7284
# Epoch 136/200
# 157/157 [==============================] - 1s 10ms/step - loss: 0.4841 - accuracy: 0.7771 - val_loss: 0.5077 - val_accuracy: 0.7282
# Epoch 137/200
# 157/157 [==============================] - 1s 9ms/step - loss: 0.4837 - accuracy: 0.7770 - val_loss: 0.5070 - val_accuracy: 0.7290
# Epoch 138/200
# 157/157 [==============================] - 1s 9ms/step - loss: 0.4833 - accuracy: 0.7771 - val_loss: 0.5067 - val_accuracy: 0.7292
# Epoch 139/200
# 157/157 [==============================] - 2s 10ms/step - loss: 0.4829 - accuracy: 0.7772 - val_loss: 0.5057 - val_accuracy: 0.7300
# Epoch 140/200
# 157/157 [==============================] - 2s 10ms/step - loss: 0.4826 - accuracy: 0.7776 - val_loss: 0.5054 - val_accuracy: 0.7304
# Epoch 141/200
# 157/157 [==============================] - 1s 9ms/step - loss: 0.4823 - accuracy: 0.7778 - val_loss: 0.5049 - val_accuracy: 0.7308
# Epoch 142/200
# 157/157 [==============================] - 1s 9ms/step - loss: 0.4821 - accuracy: 0.7780 - val_loss: 0.5055 - val_accuracy: 0.7303
# Epoch 143/200
# 157/157 [==============================] - 1s 9ms/step - loss: 0.4819 - accuracy: 0.7781 - val_loss: 0.5054 - val_accuracy: 0.7302
# Epoch 144/200
# 157/157 [==============================] - 1s 9ms/step - loss: 0.4816 - accuracy: 0.7783 - val_loss: 0.5052 - val_accuracy: 0.7304
# Epoch 145/200
# 157/157 [==============================] - 1s 10ms/step - loss: 0.4812 - accuracy: 0.7789 - val_loss: 0.5047 - val_accuracy: 0.7309
# Epoch 146/200
# 157/157 [==============================] - 2s 10ms/step - loss: 0.4808 - accuracy: 0.7790 - val_loss: 0.5044 - val_accuracy: 0.7312
# Epoch 147/200
# 157/157 [==============================] - 1s 9ms/step - loss: 0.4805 - accuracy: 0.7793 - val_loss: 0.5042 - val_accuracy: 0.7314
# Epoch 148/200
# 157/157 [==============================] - 1s 9ms/step - loss: 0.4802 - accuracy: 0.7794 - val_loss: 0.5037 - val_accuracy: 0.7318
# Epoch 149/200
# 157/157 [==============================] - 1s 9ms/step - loss: 0.4797 - accuracy: 0.7798 - val_loss: 0.5032 - val_accuracy: 0.7321
# Epoch 150/200
# 157/157 [==============================] - 1s 10ms/step - loss: 0.4794 - accuracy: 0.7799 - val_loss: 0.5028 - val_accuracy: 0.7325
# Epoch 151/200
# 157/157 [==============================] - 1s 9ms/step - loss: 0.4792 - accuracy: 0.7800 - val_loss: 0.5025 - val_accuracy: 0.7330
# Epoch 152/200
# 157/157 [==============================] - 1s 10ms/step - loss: 0.4789 - accuracy: 0.7804 - val_loss: 0.5019 - val_accuracy: 0.7334
# Epoch 153/200
# 157/157 [==============================] - 1s 9ms/step - loss: 0.4785 - accuracy: 0.7807 - val_loss: 0.5013 - val_accuracy: 0.7340
# Epoch 154/200
# 157/157 [==============================] - 1s 9ms/step - loss: 0.4782 - accuracy: 0.7810 - val_loss: 0.5011 - val_accuracy: 0.7339
# Epoch 155/200
# 157/157 [==============================] - 1s 9ms/step - loss: 0.4779 - accuracy: 0.7812 - val_loss: 0.5004 - val_accuracy: 0.7348
# Epoch 156/200
# 157/157 [==============================] - 1s 9ms/step - loss: 0.4776 - accuracy: 0.7815 - val_loss: 0.4999 - val_accuracy: 0.7351
# Epoch 157/200
# 157/157 [==============================] - 2s 10ms/step - loss: 0.4773 - accuracy: 0.7818 - val_loss: 0.4996 - val_accuracy: 0.7351
# Epoch 158/200
# 157/157 [==============================] - 1s 9ms/step - loss: 0.4770 - accuracy: 0.7820 - val_loss: 0.4994 - val_accuracy: 0.7352
# Epoch 159/200
# 157/157 [==============================] - 1s 9ms/step - loss: 0.4767 - accuracy: 0.7822 - val_loss: 0.4992 - val_accuracy: 0.7355
# Epoch 160/200
# 157/157 [==============================] - 2s 10ms/step - loss: 0.4766 - accuracy: 0.7825 - val_loss: 0.4994 - val_accuracy: 0.7355
# Epoch 161/200
# 157/157 [==============================] - 1s 10ms/step - loss: 0.4763 - accuracy: 0.7825 - val_loss: 0.4992 - val_accuracy: 0.7355
# Epoch 162/200
# 157/157 [==============================] - 1s 10ms/step - loss: 0.4760 - accuracy: 0.7826 - val_loss: 0.4988 - val_accuracy: 0.7359
# Epoch 163/200
# 157/157 [==============================] - 2s 10ms/step - loss: 0.4756 - accuracy: 0.7829 - val_loss: 0.4986 - val_accuracy: 0.7361
# Epoch 164/200
# 157/157 [==============================] - 1s 9ms/step - loss: 0.4752 - accuracy: 0.7829 - val_loss: 0.4981 - val_accuracy: 0.7364
# Epoch 165/200
# 157/157 [==============================] - 1s 9ms/step - loss: 0.4749 - accuracy: 0.7837 - val_loss: 0.4976 - val_accuracy: 0.7368
# Epoch 166/200
# 157/157 [==============================] - 1s 9ms/step - loss: 0.4746 - accuracy: 0.7839 - val_loss: 0.4973 - val_accuracy: 0.7371
# Epoch 167/200
# 157/157 [==============================] - 1s 9ms/step - loss: 0.4743 - accuracy: 0.7840 - val_loss: 0.4971 - val_accuracy: 0.7374
# Epoch 168/200
# 157/157 [==============================] - 2s 10ms/step - loss: 0.4742 - accuracy: 0.7840 - val_loss: 0.4971 - val_accuracy: 0.7374
# Epoch 169/200
# 157/157 [==============================] - 1s 10ms/step - loss: 0.4740 - accuracy: 0.7840 - val_loss: 0.4956 - val_accuracy: 0.7390
# Epoch 170/200
# 157/157 [==============================] - 1s 9ms/step - loss: 0.4734 - accuracy: 0.7846 - val_loss: 0.4950 - val_accuracy: 0.7395
# Epoch 171/200
# 157/157 [==============================] - 1s 10ms/step - loss: 0.4730 - accuracy: 0.7847 - val_loss: 0.4943 - val_accuracy: 0.7399
# Epoch 172/200
# 157/157 [==============================] - 2s 10ms/step - loss: 0.4726 - accuracy: 0.7850 - val_loss: 0.4944 - val_accuracy: 0.7398
# Epoch 173/200
# 157/157 [==============================] - 2s 10ms/step - loss: 0.4724 - accuracy: 0.7850 - val_loss: 0.4940 - val_accuracy: 0.7403
# Epoch 174/200
# 157/157 [==============================] - 2s 10ms/step - loss: 0.4721 - accuracy: 0.7853 - val_loss: 0.4935 - val_accuracy: 0.7405
# Epoch 175/200
# 157/157 [==============================] - 1s 9ms/step - loss: 0.4718 - accuracy: 0.7855 - val_loss: 0.4929 - val_accuracy: 0.7412
# Epoch 176/200
# 157/157 [==============================] - 1s 9ms/step - loss: 0.4716 - accuracy: 0.7858 - val_loss: 0.4927 - val_accuracy: 0.7415
# Epoch 177/200
# 157/157 [==============================] - 1s 9ms/step - loss: 0.4713 - accuracy: 0.7859 - val_loss: 0.4923 - val_accuracy: 0.7418
# Epoch 178/200
# 157/157 [==============================] - 1s 9ms/step - loss: 0.4710 - accuracy: 0.7861 - val_loss: 0.4920 - val_accuracy: 0.7421
# Epoch 179/200
# 157/157 [==============================] - 2s 10ms/step - loss: 0.4708 - accuracy: 0.7863 - val_loss: 0.4917 - val_accuracy: 0.7424
# Epoch 180/200
# 157/157 [==============================] - 1s 7ms/step - loss: 0.4705 - accuracy: 0.7864 - val_loss: 0.4909 - val_accuracy: 0.7431
# Epoch 181/200
# 157/157 [==============================] - 1s 5ms/step - loss: 0.4702 - accuracy: 0.7865 - val_loss: 0.4904 - val_accuracy: 0.7436
# Epoch 182/200
# 157/157 [==============================] - 1s 7ms/step - loss: 0.4699 - accuracy: 0.7867 - val_loss: 0.4896 - val_accuracy: 0.7445
# Epoch 183/200
# 157/157 [==============================] - 1s 9ms/step - loss: 0.4696 - accuracy: 0.7864 - val_loss: 0.4896 - val_accuracy: 0.7444
# Epoch 184/200
# 157/157 [==============================] - 2s 11ms/step - loss: 0.4694 - accuracy: 0.7865 - val_loss: 0.4896 - val_accuracy: 0.7444
# Epoch 185/200
# 157/157 [==============================] - 2s 10ms/step - loss: 0.4692 - accuracy: 0.7866 - val_loss: 0.4893 - val_accuracy: 0.7445
# Epoch 186/200
# 157/157 [==============================] - 2s 11ms/step - loss: 0.4689 - accuracy: 0.7866 - val_loss: 0.4889 - val_accuracy: 0.7449
# Epoch 187/200
# 157/157 [==============================] - 2s 10ms/step - loss: 0.4687 - accuracy: 0.7867 - val_loss: 0.4887 - val_accuracy: 0.7451
# Epoch 188/200
# 157/157 [==============================] - 2s 11ms/step - loss: 0.4685 - accuracy: 0.7867 - val_loss: 0.4887 - val_accuracy: 0.7451
# Epoch 189/200
# 157/157 [==============================] - 2s 10ms/step - loss: 0.4683 - accuracy: 0.7869 - val_loss: 0.4889 - val_accuracy: 0.7448
# Epoch 190/200
# 157/157 [==============================] - 2s 10ms/step - loss: 0.4680 - accuracy: 0.7871 - val_loss: 0.4887 - val_accuracy: 0.7449
# Epoch 191/200
# 157/157 [==============================] - 2s 10ms/step - loss: 0.4678 - accuracy: 0.7871 - val_loss: 0.4884 - val_accuracy: 0.7451
# Epoch 192/200
# 157/157 [==============================] - 2s 10ms/step - loss: 0.4676 - accuracy: 0.7872 - val_loss: 0.4882 - val_accuracy: 0.7454
# Epoch 193/200
# 157/157 [==============================] - 2s 10ms/step - loss: 0.4673 - accuracy: 0.7875 - val_loss: 0.4882 - val_accuracy: 0.7454
# Epoch 194/200
# 157/157 [==============================] - 2s 10ms/step - loss: 0.4672 - accuracy: 0.7876 - val_loss: 0.4883 - val_accuracy: 0.7453
# Epoch 195/200
# 157/157 [==============================] - 2s 10ms/step - loss: 0.4669 - accuracy: 0.7879 - val_loss: 0.4880 - val_accuracy: 0.7457
# Epoch 196/200
# 157/157 [==============================] - 2s 10ms/step - loss: 0.4666 - accuracy: 0.7879 - val_loss: 0.4881 - val_accuracy: 0.7456
# Epoch 197/200
# 157/157 [==============================] - 2s 10ms/step - loss: 0.4665 - accuracy: 0.7880 - val_loss: 0.4881 - val_accuracy: 0.7456
# Epoch 198/200
# 157/157 [==============================] - 2s 10ms/step - loss: 0.4662 - accuracy: 0.7882 - val_loss: 0.4876 - val_accuracy: 0.7462
# Epoch 199/200
# 157/157 [==============================] - 2s 10ms/step - loss: 0.4659 - accuracy: 0.7885 - val_loss: 0.4872 - val_accuracy: 0.7465
# Epoch 200/200
# 157/157 [==============================] - 2s 10ms/step - loss: 0.4657 - accuracy: 0.7885 - val_loss: 0.4871 - val_accuracy: 0.7466
# ['loss', 'accuracy'] [0.487091988325119, 0.7465500235557556]
# ['loss', 'accuracy'] [0.510762631893158, 0.7404000163078308]

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 2)                 1460
#
# =================================================================
# Total params: 1,460
# Trainable params: 1,460
# Non-trainable params: 0
# _________________________________________________________________

# %%
test_loss, test_acc = model.evaluate(x_test, y_test)
print('Perte sur les données de test :', test_loss)
print('Précision sur les données de test :', test_acc)
train_loss, train_acc = model.evaluate(x_train, y_train)
print('Perte sur les données d\'entraînement :', train_loss)
print('Précision sur les données d\'entraînement :', train_acc)
# Out:
# 625/625 [==============================] - 2s 3ms/step - loss: 0.5088 - accuracy: 0.8263
# Perte sur les données de test : 0.5088198781013489
# Précision sur les données de test : 0.8263499736785889
# 625/625 [==============================] - 2s 3ms/step - loss: 0.5136 - accuracy: 0.8140
# Perte sur les données d'entraînement : 0.5135793089866638
# Précision sur les données d'entraînement : 0.8139500021934509

# %%
# Évaluer la performance du modèle sur les données de test
score = model.evaluate(x_test, y_test, verbose=0)

# Calculer les prédictions pour les données de test
y_pred = model.predict(x_test)

# Convertir les prédictions en classes
y_pred_classes = np.argmax(y_pred, axis=1)
y_test_classes = np.argmax(y_test, axis=1)

# Calculer la précision, le rappel, la F-mesure et d'autres métriques de performance
from sklearn.metrics import classification_report
report = classification_report(y_test_classes, y_pred_classes)
print(report)

# Calculer la matrice de confusion
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test_classes, y_pred_classes)
print(cm)
# Out:
# 625/625 [==============================] - 1s 2ms/step
#               precision    recall  f1-score   support
#
#            0       0.84      0.81      0.82     10000
#            1       0.82      0.84      0.83     10000
#
#     accuracy                           0.83     20000
#    macro avg       0.83      0.83      0.83     20000
# weighted avg       0.83      0.83      0.83     20000
#
# [[8102 1898]
#  [1575 8425]]

# %%
import json
import yaml
from keras.models import load_model
## save the model
json_string = model.to_json() # as json 
open('HRD.json', 'w').write(json_string) 
# Convertir la configuration JSON en YAML
yaml_string = yaml.dump(json.loads(json_string), default_flow_style=False)

# Enregistrer la configuration en tant que fichier YAML
with open('HRD.yaml', 'w') as f:
    f.write(yaml_string)

# %%
import tensorflow as tf
# save the weights in h5 format 
model.save_weights('HRD.h5') 
# Save the model to a file
model.save('HRD.h5')
